# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
#can use this in the future as path
mouse_metadata_path_relative = "Resources/Mouse_metadata.csv"
study_results_path_relative = "Resources/Study_results.csv"

mouse_metadata_path_full = "C:/Users/leahm/Matplotlib-/Resources/Mouse_metadata.csv"
study_results_path_full = "C:/Users/leahm/Matplotlib-/Resources/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path_full)
study_results = pd.read_csv(study_results_path_full)

# Combine the data into a single DataFrame
combined_results_data= pd.merge(study_results, mouse_metadata, how="left", on=["Mouse ID", "Mouse ID"])
study_results.head()

# Display the data table for preview
combined_results_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
len(combined_results_data["Mouse ID"].unique())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse = combined_results_data.loc[combined_results_data.duplicated(subset= ['Mouse ID','Timepoint']),'Mouse ID'].unique()
duplicate_mouse
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_ID = combined_results_data.loc[combined_results_data["Mouse ID"]=="g989"]
duplicate_mouse_ID.head(2)
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107     g989          0                45.0                 0     Propriva
# 137     g989          0                45.0                 0     Propriva
#
#         Sex  Age_months  Weight (g)
# 107  Female          21          26
# 137  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data = combined_results_data[combined_results_data['Mouse ID'].isin(duplicate_mouse) == False]                         
clean_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_data["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
mode_scipy = st.mode(tumor_volumn)
print("The mode of the tumor_volumn is {mode_scipy}")
mean_numpy = np.mean(tumor_volumn)
print(f"The mode of the tumor_volumn is {mean_numpy}")
median_numpy = np.median(tumor_volumn)
print(f"The median of the tumor_volumn is {median_numpy}")

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# ----> 2 mode_scipy = st.mode(tumor_volumn)
#       3 print("The mode of the tumor_volumn is {mode_scipy}")
#       4 mean_numpy = np.mean(tumor_volumn)
#
# NameError: name 'tumor_volumn' is not defined

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
mean_numpy = np.mean(tumor_volumn)
var_numpy

# Using the aggregation method, produce the same summary statistics in a single line
df = pd.DataFrame(data)

x = df.aggregate(["sum"])

print(x)

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
Mouse_ID = X_axis
Timepoint = y_axis

plt.bar(Mouse_ID, Timepoint_axis, users,color ='', alpha=0.5, align="center")

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
plt.bar(x_axis, users,color ='', alpha=0.5, align="center")

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
female_male.pie(sizes, explode=explode, labels=labels, colors=colors, autopct=%1. 1f%%, shadow=true)
female_versus_male = distribution_df[["Female","Male"]]
female_and_male = female_and_male.set.index("distribution")
female_versus_male.head()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct=%1. 1f%%, shadow=true, startangle=140)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merge_df

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)
tumor volumn data []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds
quartiles = 
lowerq = quartiels[]
upperq = []
iqr = uuperq -lowerq
print(f"The lower quartile of occupancy is{lowerq}")
outlier_occupancy = _data.loc[ _data("")<lower_bound][ _data("")<upper_bound]

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.boxplot(tumor_volumn, showmeans=True)
plt.grid()
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
plt.scatter()["tumor volume"], _data ["time point"], c 
plt.title("Single Mouse Treated with Capomulin")
plt.xlabel("Tumor Volume")
plt.ylabel("Timepoint")
plt.show

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
x_limit = 
x_axis = np.arrange(0, xlimit, 1)
plt.scatter(x_axis, data, marker="", facecolors="", edgecolors="
            s=x_asix, apha=0.75")

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
mouse_weight = mouse.weight.corr()
average_tumor_volumn.unstack().sort_values()
print(f"The correlation coefficient between mouse weight and average tumor volumn is {round(st.pearsonr(mouse_weight, average_tumor_volumn)[0],2)}")
